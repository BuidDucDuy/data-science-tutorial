# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# line
# scatter
# car
# hist
# sublots

# %%
x = np.linspace(0 , 10 , 100)
x[:5]
# Out:
# array([0.       , 0.1010101, 0.2020202, 0.3030303, 0.4040404])

# %%
fig , ax = plt.subplots(figsize = (6,6))
ax.plot(x,x)
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# oo api

# %%
#prepare data
rng = np.random.RandomState(0)
x = rng.rand(100)
y = rng.rand(100)
x
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#        0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152,
#        0.79172504, 0.52889492, 0.56804456, 0.92559664, 0.07103606,
#        0.0871293 , 0.0202184 , 0.83261985, 0.77815675, 0.87001215,
#        0.97861834, 0.79915856, 0.46147936, 0.78052918, 0.11827443,
#        0.63992102, 0.14335329, 0.94466892, 0.52184832, 0.41466194,
#        0.26455561, 0.77423369, 0.45615033, 0.56843395, 0.0187898 ,
#        0.6176355 , 0.61209572, 0.616934  , 0.94374808, 0.6818203 ,
#        0.3595079 , 0.43703195, 0.6976312 , 0.06022547, 0.66676672,
#        0.67063787, 0.21038256, 0.1289263 , 0.31542835, 0.36371077,
#        0.57019677, 0.43860151, 0.98837384, 0.10204481, 0.20887676,
#        0.16130952, 0.65310833, 0.2532916 , 0.46631077, 0.24442559,
#        0.15896958, 0.11037514, 0.65632959, 0.13818295, 0.19658236,
#        0.36872517, 0.82099323, 0.09710128, 0.83794491, 0.09609841,
#        0.97645947, 0.4686512 , 0.97676109, 0.60484552, 0.73926358,
#        0.03918779, 0.28280696, 0.12019656, 0.2961402 , 0.11872772,
#        0.31798318, 0.41426299, 0.0641475 , 0.69247212, 0.56660145,
#        0.26538949, 0.52324805, 0.09394051, 0.5759465 , 0.9292962 ,
#        0.31856895, 0.66741038, 0.13179786, 0.7163272 , 0.28940609,
#        0.18319136, 0.58651293, 0.02010755, 0.82894003, 0.00469548])

# %%
fig , ax = plt.subplots()
size = 1000*rng.rand(100)
ax.scatter(x,y)

# %%
# bar
price = {"car":10 , "lap" : 200 , "table" :400 }
fig , ax = plt.subplots()
ax.bar(price.keys() , price.values());
ax.set(title = "price" , ylabel="gia$/")
# Out:
# [Text(0.5, 1.0, 'price'), Text(0, 0.5, 'gia$/')]

# %%
fig , ax = plt.subplots()
ax.barh(list(price.keys()) , list(price.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
#histogram
#prepare data
height = np.random.normal(170 , 10 , 255)
height
# Out:
# array([168.83095213, 173.39147816, 154.81705927, 167.37241752,
#        174.83540777, 174.45783662, 179.58803299, 181.88963682,
#        174.66459378, 171.00941262, 163.76755584, 172.44611996,
#        158.70203956, 182.84598956, 163.57119369, 180.51425701,
#        173.34595914, 165.18495522, 189.46259124, 165.90376568,
#        157.61905586, 163.22440565, 152.17985159, 174.76526284,
#        180.84695683, 168.25880765, 162.61921977, 148.93528349,
#        170.74770877, 185.7820078 , 156.4572967 , 174.04154929,
#        171.88558456, 163.55914825, 174.44896415, 168.7507752 ,
#        163.73037483, 175.41984567, 167.96208715, 171.05729908,
#        179.40523784, 144.70204986, 153.58630892, 154.70727699,
#        152.74821272, 177.08269991, 169.60544264, 185.74863068,
