# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
np.array([3.14 , 1 , 2 , 45])
# Out:
# array([ 3.14,  1.  ,  2.  , 45.  ])

# %%
np.array([3.94 , 8 , 5 , 6],dtype='int64')
# Out:
# array([3, 8, 5, 6])

# %%
a1 = np.array([[1,2,3,],[4,5,6]])

# %%
a1.shape
# Out:
# (2, 3)

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
a1.size
# Out:
# 6
