# %%
import numpy as np

# %%
a = np.arange(3)
print(a)
# Out:
# [0 1 2]

# %%
a = a + 5
print(a)
# Out:
# [5 6 7]

# %%
b = np.ones((3,3),dtype=int)
print(b)
print(a*b)
# Out:
# [[1 1 1]
#  [1 1 1]
#  [1 1 1]]
# [[5 6 7]
#  [5 6 7]
#  [5 6 7]]

# %%
c = np.arange(3)
print(c)
d= np.reshape(c ,(3,1))
print(d)
# Out:
# [0 1 2]
# [[0]
#  [1]
#  [2]]

# %%
print(c+d)
# Out:
# [[0 1 2]
#  [1 2 3]
#  [2 3 4]]
